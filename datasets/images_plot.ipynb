# %%
import os
from glob import glob
import matplotlib.pyplot as plt
import tifffile
import numpy as np
from glob import glob

root_dir = "."  # Specify the root directory to search

tif_list = []
for current_dir, _, _ in os.walk(root_dir):
    # print(current_dir)
    tif_files = glob(os.path.join(current_dir, "*.tif"))
    
    for tif_path in tif_files:
        print(tif_path)
        tif_list.append(tif_path)
# Out:
# ./simulate_-2.51dBSNR_1000frames_demo/simulate_-2.51dBSNR_1000frames.tif
# ./fish_wholebrain_demo/fish_wholebrain.tif
# ./NP_2D_demo/NP_2D.tif
# ./mouse_spine_demo/mouse_spine.tif
# ./fish_localbrain_demo/fish_localbrain.tif
# ./ATP_2D_demo/ATP_2D.tif
# ./drosophila_demo/drosophila.tif
# ./ATP_3D_demo/ATP_3D.tif
# ./NP_3D_demo/NP_3D.tif

# %%
tif_list
# Out:
# ['./simulate_-2.51dBSNR_1000frames_demo/simulate_-2.51dBSNR_1000frames.tif',
#  './fish_wholebrain_demo/fish_wholebrain.tif',
#  './NP_2D_demo/NP_2D.tif',
#  './mouse_spine_demo/mouse_spine.tif',
#  './fish_localbrain_demo/fish_localbrain.tif',
#  './ATP_2D_demo/ATP_2D.tif',
#  './drosophila_demo/drosophila.tif',
#  './ATP_3D_demo/ATP_3D.tif',
#  './NP_3D_demo/NP_3D.tif']

# %%
    img = tifffile.imread('./fish_localbrain_demo/fish_localbrain.tif')
    print(img.shape, './fish_localbrain_demo/fish_localbrain.tif')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_46507/1557868724.py in ?()
# ----> 1 img = tifffile.imread('./fish_localbrain_demo/fish_localbrain.tif')
#       2 print(img.shape, './fish_localbrain_demo/fish_localbrain.tif')
#
# ~/miniconda3/envs/RetNetOCR/lib/python3.8/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1090
#    1091         if isinstance(files, str) or not isinstance(
#    1092             files, collections.abc.Sequence
#    1093         ):
# -> 1094             with TiffFile(
#    1095                 files,
# ...

# %%
for tif_path in tif_list : 
    img = tifffile.imread(tif_path)
    print(img.shape, tif_path)
# Out:
# (1000, 490, 490) ./simulate_-2.51dBSNR_1000frames_demo/simulate_-2.51dBSNR_1000frames.tif
# (9800, 400, 485) ./fish_wholebrain_demo/fish_wholebrain.tif
# (6440, 512, 512) ./NP_2D_demo/NP_2D.tif
# (6500, 492, 978) ./mouse_spine_demo/mouse_spine.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/34/q4vcf0710b9cm75lplc7sx2w0000gn/T/ipykernel_46507/3992575361.py in ?()
#       1 for tif_path in tif_list :
# ----> 2     img = tifffile.imread(tif_path)
#       3     print(img.shape, tif_path)
#
# ~/miniconda3/envs/RetNetOCR/lib/python3.8/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
# ...

# %%
tif_list = ['./simulate_-2.51dBSNR_1000frames_demo/simulate_-2.51dBSNR_1000frames.tif',
 './fish_wholebrain_demo/fish_wholebrain.tif',
 './NP_2D_demo/NP_2D.tif',
 './mouse_spine_demo/mouse_spine.tif',
 './fish_localbrain_demo/fish_localbrain.tif',
 './ATP_2D_demo/ATP_2D.tif',
 './drosophila_demo/drosophila.tif',
 './ATP_3D_demo/ATP_3D.tif',
 './NP_3D_demo/NP_3D.tif']
tif_list.remove('./fish_localbrain_demo/fish_localbrain.tif')

# %%
for tif_path in tif_list : 
    img = tifffile.imread(tif_path)
    print(img.shape, tif_path)
    t = 0
    plt.imshow(img[t], cmap='gray')
    # plt.title(tif_path.split("/")[-1],' t=0')
    plt.axis('off')
    plt.show()
# Out:
# (1000, 490, 490) ./simulate_-2.51dBSNR_1000frames_demo/simulate_-2.51dBSNR_1000frames.tif
# (9800, 400, 485) ./fish_wholebrain_demo/fish_wholebrain.tif
# (6440, 512, 512) ./NP_2D_demo/NP_2D.tif
# (6500, 492, 978) ./mouse_spine_demo/mouse_spine.tif
# (7100, 476, 476) ./ATP_2D_demo/ATP_2D.tif
# (14951, 442, 442) ./drosophila_demo/drosophila.tif
# (3600, 512, 512) ./ATP_3D_demo/ATP_3D.tif
# (2000, 512, 512) ./NP_3D_demo/NP_3D.tif

# %%
for tif_path in tif_list : 
    img = tifffile.imread(tif_path)
    print(img.shape, tif_path)
    max_projection = np.max(img, axis=0)
    plt.imshow(max_projection, cmap='gray')
    # plt.title(tif_path.split("/")[-1],' Maximum Intensity Projection')
    plt.axis('off')
    plt.show()
# Out:
# (1000, 490, 490) ./simulate_-2.51dBSNR_1000frames_demo/simulate_-2.51dBSNR_1000frames.tif
# (9800, 400, 485) ./fish_wholebrain_demo/fish_wholebrain.tif
# (6440, 512, 512) ./NP_2D_demo/NP_2D.tif
# (6500, 492, 978) ./mouse_spine_demo/mouse_spine.tif
# (7100, 476, 476) ./ATP_2D_demo/ATP_2D.tif
# (14951, 442, 442) ./drosophila_demo/drosophila.tif
# (3600, 512, 512) ./ATP_3D_demo/ATP_3D.tif
# (2000, 512, 512) ./NP_3D_demo/NP_3D.tif

# %%
import napari
import tifffile
from glob import glob

# 이미지 로드
# napari viewer로 시각화
viewer = napari.Viewer()
viewer.add_image(img, name='3D Image')

napari.run()

# %%
import os
from glob import glob

# List your directory names (adjust as needed)
directory_names = [
    "DataFolderIs_ATP_2D_demo_202405311601_ModelFolderIs_ATP_2D_best_model_demo",
    "DataFolderIs_ATP_3D_demo_202405311615_ModelFolderIs_ATP_3D_best_model_demo",
    # ... (Add the rest of your directory names here)
    "DataFolderIs_simulate_-2.51dBSNR_1000frames_demo_202405311513_ModelFolderIs_simulate_-2.51dBSNR_1000frames_best_model_demo"
]

# Iterate through each directory
for dir_name in directory_names:
    # Construct path to the "best_model" subdirectory
    best_model_dir = os.path.join(dir_name, "best_model")  
    
    # Check if the "best_model" directory exists
    if os.path.exists(best_model_dir):  
        # Find all .tif files within the "best_model" directory
        tif_files = glob(os.path.join(best_model_dir, "*.tif"))  
        
        # Print the path of each found .tif file
        for tif_file in tif_files:  
            print(tif_file)
